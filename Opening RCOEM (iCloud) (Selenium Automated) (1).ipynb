# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %%
user = input("Enter you username:")
pwd = input("Enter your password:")

# %%
import time

# %%
chromedriver_path = r"C:/Users/hp/Downloads/chromedriver-win64/chromedriver.exe"

brave_path = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\Brave.exe"
    
options = Options()
options.add_argument("--headless")  # Run in headless mode
options.add_argument("--disable-gpu")
options.binary_location = brave_path
service = Service(chromedriver_path)
driver = webdriver.Chrome(service = service, options = options)

driver.get("https://rbu.icloudems.com/corecampus/index.php")
username = driver.find_element(By.XPATH, '//*[@id="useriid"]')
username.send_keys(user, Keys.ENTER)

password = driver.find_element(By.XPATH, '//*[@id="actlpass"]')
password.send_keys(pwd, Keys.ENTER)

at = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[5]/div/div/div[2]/a/img')
at.click()

subjects = []
attendence = []
attended = []


overall = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[23]/td[3]').text
overall = float(overall.replace('%', ''))

overall_fraction = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[23]/td[2]').text

attended_classes, total_classes = map(int, overall_fraction.split('/'))

required_percentage = 75

if overall < required_percentage:
    classes = max(0, (0.75 * total_classes - attended_classes) / 0.25)  
    print(f"Attend at least {attended_classes - (int(classes) + 1)} more classes to reach 75%")
else:
    classes = max(0, (attended_classes - 0.75 * total_classes) / 0.75)  
    print(f"You can skip {int(classes)} classes and still be above 75%")


# Computer Vision
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[14]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[14]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[14]/td[5]/div')
attended.append(attend.text)


# Computer Vision Lab
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[15]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[15]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[15]/td[5]/div')
attended.append(attend.text)


# Software Testing
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[16]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[16]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[16]/td[5]/div')
attended.append(attend.text)


# Software Testing Lab
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[17]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[17]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[17]/td[5]/div')
attended.append(attend.text)



# Data Analysis and Algorithms
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[11]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[11]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[11]/td[5]/div')
attended.append(attend.text)


# Deep Learning
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[12]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[12]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[12]/td[5]/div')
attended.append(attend.text)


# Deep Learning Lab
subject = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[13]/td[2]')
print(subject.text)
subjects.append(subject.text)

p = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[13]/td[6]')
percent = p.text
print(percent)
attendence.append(percent)

attend = driver.find_element(By.XPATH, '/html/body/div[1]/div/div[1]/div[3]/div[2]/div[2]/div[3]/div/div/table/tbody/tr[13]/td[5]/div')
attended.append(attend.text)

print(subjects)
print(attendence)
print(attended)

time.sleep(5)

driver.quit()
# Out:
# Attend at least 259 more classes to reach 75%
# Computer Vision
# 35
# Computer Vision Lab
# 62.5
# Software Engineering and Testing Methodologies
# 50
# Software Engineering and Testing Methodologies Lab
# 66.67
# Design and Analysis of Algorithm
# 36.36
# Deep Learning -I
# 33.33
# Deep Learning - I Lab
# 50
# ['Computer Vision', 'Computer Vision Lab', 'Software Engineering and Testing Methodologies', 'Software Engineering and Testing Methodologies Lab', 'Design and Analysis of Algorithm', 'Deep Learning -I', 'Deep Learning - I Lab']
# ['35', '62.5', '50', '66.67', '36.36', '33.33', '50']
# ['7/20', '10/16', '10/20', '8/12', '8/22', '5/15', '6/12']

# %%
threshold = 60
for i in range(len(subjects)):
    a, total = map(int, attended[i].split('/'))
    
    if (a / total) * 100 < threshold:
        # Find how many more classes to attend
        extra_classes = 0
        while (a / total) * 100 < threshold:
            a += 1
            total += 1
            extra_classes += 1
        print(f"{subjects[i]}: Attend at least {extra_classes} more classes to cross 60%")
    
    else:
        # Find how many classes can be bunked
        bunkable = 0
        temp_a, temp_total = a, total
        while ((temp_a / temp_total) * 100) >= threshold:
            temp_a -= 1
            temp_total -= 1
            bunkable += 1
        
        # The last decrement takes it below 60%, so we subtract one from the bunkable count
        bunkable -= 1  
        print(f"{subjects[i]}: You can bunk {bunkable} classes and still stay above 60%")
    print()
# Out:
# Computer Vision: Attend at least 13 more classes to cross 60%
#
# Computer Vision Lab: You can bunk 1 classes and still stay above 60%
#
# Software Engineering and Testing Methodologies: Attend at least 5 more classes to cross 60%
#
# Software Engineering and Testing Methodologies Lab: You can bunk 2 classes and still stay above 60%
#
# Design and Analysis of Algorithm: Attend at least 13 more classes to cross 60%
#
# Deep Learning -I: Attend at least 10 more classes to cross 60%
#
# Deep Learning - I Lab: Attend at least 3 more classes to cross 60%

# %%
'''
chromedriver_path = r"C:/Users/hp/Downloads/chromedriver-win64/chromedriver.exe"

brave_path = r"C:\Program Files\BraveSoftware\Brave-Browser\Application\Brave.exe"
    
options = Options()
options.binary_location = brave_path
service = Service(chromedriver_path)
driver = webdriver.Chrome(service = service, options = options)

driver.get("https://rcoem.in/login.htm")
username = driver.find_element(By.XPATH, '//*[@id="j_username"]')
username.send_keys(user, Keys.ENTER)

password = driver.find_element(By.XPATH, '//*[@id="password-1"]')
password.send_keys(pwd, Keys.ENTER)

at = driver.find_element(By.XPATH, '//*[@id="stud2"]/h2')
at.click()
                               

driver.quit()
'''
